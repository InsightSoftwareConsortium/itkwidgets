# %%
import piplite
await piplite.install('itkwidgets==1.0a23')

# %%
from itkwidgets import view
import imageio.v2 as imageio

# %%
stent = imageio.imread('imageio:stent.npz')

# %%
view(stent, rotate=True)
# Out:
#                 <img id="screenshot_imjoy_window_54028d9c-f489-4a44-adee-1d3051829396" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_54028d9c-f489-4a44-adee-1d3051829396");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_54028d9c-f489-4a44-adee-1d3051829396");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="c39bc1af-4131-49cd-a1fe-c3bb383aef71"></div>
