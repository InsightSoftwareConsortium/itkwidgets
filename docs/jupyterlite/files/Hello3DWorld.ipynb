# %%
import piplite
await piplite.install('itkwidgets==1.0a24')

# %%
from itkwidgets import view
import imageio.v2 as imageio

# %%
stent = imageio.imread('imageio:stent.npz')

# %%
view(stent, rotate=True)
# Out:
#                 <img id="screenshot_imjoy_window_8d771fc1-e626-4fb4-b5a7-1bc1f74b8761" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_8d771fc1-e626-4fb4-b5a7-1bc1f74b8761");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_8d771fc1-e626-4fb4-b5a7-1bc1f74b8761");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="b92dfad2-1c77-4121-b950-ef89b5c5a4bf"></div>
