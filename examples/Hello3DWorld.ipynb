# %%
import sys

# !{sys.executable} -m pip install -q imageio "itkwidgets>=1.0a6"

# %%
from itkwidgets import view

try:
    import imageio.v2 as imageio
except ImportError:
    # Colab
    import imageio

# %%
stent = imageio.imread('imageio:stent.npz')

# %%
viewer = view(stent, rotate=True)
viewer
# Out:
#                 <img id=screenshot_imjoy_window_d59323c8-e979-4c25-8c4a-9994168df8ef src=data:image/png;base64,...>
#                 <script id="script_imjoy_window_d59323c8-e979-4c25-8c4a-9994168df8ef" type="text/javascript">
#                     var container = document.getElementById("script_imjoy_window_d59323c8-e979-4c25-8c4a-9994168df8ef").parentNode;
#                     var image = document.getElementById("screenshot_imjoy_window_d59323c8-e979-4c25-8c4a-9994168df8ef");
#                     if (!image) {
#                         image = document.createElement("img");
#                         image.id = "screenshot_imjoy_window_d59323c8-e979-4c25-8c4a-9994168df8ef";
#                         container.appendChild(image);
#                     }
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_d59323c8-e979-4c25-8c4a-9994168df8ef");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="2840b16f-3593-47a8-bed5-3411b732d98b"></div>

# %%
viewer.set_image_gradient_opacity(0.4)
