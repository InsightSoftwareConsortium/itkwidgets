# %%
import sys

# !{sys.executable} -m pip install -q "itkwidgets>=1.0a5" imageio

# %%
from itkwidgets import view

try:
    import imageio.v2 as imageio
except ImportError:
    # Colab
    import imageio

# %%
stent = imageio.imread('imageio:stent.npz')

# %%
viewer = view(stent, rotate=True)
viewer
# Out:
#                 <img id="screenshot" src="data:image/png;base64,..." />
#                 <script type="text/javascript">
#                     var viewer = document.getElementById("imjoy_window_9727a8fc-0685-4ba1-9b3f-a53e477684ff");
#                     var image = document.getElementById("screenshot");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="629ba980-8998-4222-9bc9-095de24be0e2"></div>

# %%
viewer.set_image_gradient_opacity(0.4)
