# %%
import sys

# !{sys.executable} -m pip install -q imageio "itkwidgets>=1.0a6"

# %%
from itkwidgets import view

try:
    import imageio.v2 as imageio
except ImportError:
    # Colab
    import imageio

# %%
stent = imageio.imread('imageio:stent.npz')

# %%
viewer = view(stent, rotate=True)
viewer
# Out:
#                 <img id="screenshot_imjoy_window_1f3c3ab7-0557-4056-befe-90b90750d626" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_1f3c3ab7-0557-4056-befe-90b90750d626");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_1f3c3ab7-0557-4056-befe-90b90750d626");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="b5c4ec64-5162-4988-95b3-93a831e85fe9"></div>
