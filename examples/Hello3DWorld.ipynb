# %%
import sys

# !{sys.executable} -m pip install itkwidgets imageio

# %%
from itkwidgets import view

import imageio.v2 as imageio

# %%
stent = imageio.imread('imageio:stent.npz')

# %%
view(stent)
# Out:
# <div id="f0775c37-7067-4b89-a401-b0fc7a8cfaad"></div>
