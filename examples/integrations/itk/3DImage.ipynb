# %%
# Install dependencies for this example
import sys

# !{sys.executable} -m pip install -q --upgrade --pre itk-io "itkwidgets>=1.0a6"

# %%
from urllib.request import urlretrieve
import os

import itk

from itkwidgets import view

# %%
# Download data
file_name = '005_32months_T2_RegT1_Reg2Atlas_ManualBrainMask_Stripped.nrrd'
if not os.path.exists(file_name):
    url = 'https://data.kitware.com/api/v1/file/564a5b078d777f7522dbfaa6/download'
    urlretrieve(url, file_name)

# %%
image = itk.imread(file_name)
view(image, rotate=True, gradient_opacity=0.4)
# Out:
#                 <img id=screenshot_imjoy_window_2219c8a0-46e5-40e2-a62f-b1ce05df5ad9 src=data:image/png;base64,...>
#                 <script id="script_imjoy_window_2219c8a0-46e5-40e2-a62f-b1ce05df5ad9" type="text/javascript">
#                     var container = document.getElementById("script_imjoy_window_2219c8a0-46e5-40e2-a62f-b1ce05df5ad9").parentNode;
#                     var image = document.getElementById("screenshot_imjoy_window_2219c8a0-46e5-40e2-a62f-b1ce05df5ad9");
#                     if (!image) {
#                         image = document.createElement("img");
#                         image.id = "screenshot_imjoy_window_2219c8a0-46e5-40e2-a62f-b1ce05df5ad9";
#                         container.appendChild(image);
#                     }
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_2219c8a0-46e5-40e2-a62f-b1ce05df5ad9");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="057664b3-e7a4-4d15-9cb5-d21b975cdedd"></div>
