# %% [markdown]
# ### Try this notebook in Google Colab, Binder or SageMaker!
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/InsightSoftwareConsortium/itkwidgets/blob/main/examples/integrations/itk/DICOM.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/InsightSoftwareConsortium/itkwidgets/HEAD?labpath=examples%2Fintegrations%2Fitk%2FDICOM.ipynb)
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github.com/InsightSoftwareConsortium/itkwidgets/blob/main/examples/integrations/itk/DICOM.ipynb)

# %%
# Install dependencies for this example
import sys

# !{sys.executable} -m pip install -q --upgrade --pre itk-io tqdm pooch "itkwidgets[all]>=1.0a17"

# %%
from itkwidgets import view

import pooch
import itk
from pathlib import Path

# %%
dicom_files = pooch.retrieve('https://data.kitware.com/api/v1/item/6347159711dab81428208e24/download',
                             known_hash='7ae09068c9b807b2276feb3427cebf82865ae39efc954f0222a4eec1acd6554d',
                             processor=pooch.Unzip(),
                             progressbar=True)

# %%
# ITK will sort the DICOM series into a volume properly using spatial metadata
# Pass the directory containing the DICOM series to itk.imread
image = itk.imread(Path(dicom_files[0]).parent)

# %%
view(image)
# Out:
#                 <img id="screenshot_imjoy_window_ff9ae1c8-bc71-4344-b184-64021e859ea7" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_ff9ae1c8-bc71-4344-b184-64021e859ea7");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_ff9ae1c8-bc71-4344-b184-64021e859ea7");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="eb9a9d50-fddf-4dd2-b985-558e45daac58"></div>
