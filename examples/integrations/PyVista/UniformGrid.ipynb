# %% [markdown]
# ### Try this notebook in Google Colab as well!
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/InsightSoftwareConsortium/itkwidgets/blob/main/examples/integrations/PyVista/UniformGrid.ipynb)

# %%
# Install dependencies for this example
import sys

# !{sys.executable} -m pip install -q pyvista "itkwidgets[all]>=1.0a16"

# %%
import pyvista
from pyvista import examples

from itkwidgets import view

# %%
dataset = examples.load_uniform()
dataset
# Out:
# UniformGrid (0x7f1ae6cec8e0)
#   N Cells:	729
#   N Points:	1000
#   X Bounds:	0.000e+00, 9.000e+00
#   Y Bounds:	0.000e+00, 9.000e+00
#   Z Bounds:	0.000e+00, 9.000e+00
#   Dimensions:	10, 10, 10
#   Spacing:	1.000e+00, 1.000e+00, 1.000e+00
#   N Arrays:	2

# %%
view(dataset)
# Out:
#                 <img id=screenshot_imjoy_window_71adfe38-0e1f-4546-a178-8a72868f509e src=data:image/png;base64,...>
#                 <script id="script_imjoy_window_71adfe38-0e1f-4546-a178-8a72868f509e" type="text/javascript">
#                     var container = document.getElementById("script_imjoy_window_71adfe38-0e1f-4546-a178-8a72868f509e").parentNode;
#                     var image = document.getElementById("screenshot_imjoy_window_71adfe38-0e1f-4546-a178-8a72868f509e");
#                     if (!image) {
#                         image = document.createElement("img");
#                         image.id = "screenshot_imjoy_window_71adfe38-0e1f-4546-a178-8a72868f509e";
#                         container.appendChild(image);
#                     }
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_71adfe38-0e1f-4546-a178-8a72868f509e");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="e60c7147-c292-4085-b4c7-d11bc956ccc3"></div>
