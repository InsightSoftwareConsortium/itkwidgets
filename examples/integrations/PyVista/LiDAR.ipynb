# %% [markdown]
# ### Try this notebook in Google Colab as well!
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/InsightSoftwareConsortium/itkwidgets/blob/main/examples/integrations/PyVista/LiDAR.ipynb)

# %%
# Install dependencies for this example
import sys

# !{sys.executable} -m pip install -q pyvista "itkwidgets>=1.0a6"

# %%
import pyvista
from pyvista import examples

from itkwidgets import view

# %%
lidar = examples.download_lidar()

clipped = lidar.clip(origin=(0, 0, 1.76e3), normal=(0, 0, 1))

# %%
view(point_sets=clipped)
# Out:
#                 <img id=screenshot_imjoy_window_bf63f00c-5690-4270-a8a6-bb6e7a4aa161 src=data:image/png;base64,...>
#                 <script id="script_imjoy_window_bf63f00c-5690-4270-a8a6-bb6e7a4aa161" type="text/javascript">
#                     var container = document.getElementById("script_imjoy_window_bf63f00c-5690-4270-a8a6-bb6e7a4aa161").parentNode;
#                     var image = document.getElementById("screenshot_imjoy_window_bf63f00c-5690-4270-a8a6-bb6e7a4aa161");
#                     if (!image) {
#                         image = document.createElement("img");
#                         image.id = "screenshot_imjoy_window_bf63f00c-5690-4270-a8a6-bb6e7a4aa161";
#                         container.appendChild(image);
#                     }
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_bf63f00c-5690-4270-a8a6-bb6e7a4aa161");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="af183a89-9931-4298-8070-16ca01d7bd51"></div>
